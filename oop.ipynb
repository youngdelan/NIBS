# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/oop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import math
import math
square_root=math.sqrt(4)
print(square_root)
# Out:
# 2.0

# %%
#oop in python                         #attributes:
#class:employee
#attribute:employee ID
#attribute:name
#attribute:gender            #objects are used to access the classes
#attribute:age

# %%
#classes
class bike:
  name=""
  gear=0
