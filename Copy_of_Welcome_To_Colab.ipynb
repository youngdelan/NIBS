# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#salary calculator

payroll_number=input("enter your payroll number: ")
name=input("enter enployee name: ")
gender=input("enter your gender: ")
job_group=input("enter your job group: ")
basic_salary=int(input("enter your basic salary: "))


#allowance based on job
if job_group=="J":
  allowance=5000
  print("allowance",allowance)
elif job_group=="K":
  allowance=5500
  print("allowance",allowance)
elif job_group=="L":
  allowance=6000
  print("allowance",allowance)
elif job_group=="M":
  allowance=6500
  print("allowance",allowance)
else:
  allowance=0
  print("invalid job group allowance")
gross_pay=allowance+basic_salary
print(" gross_pay",gross_pay)
taxes=(basic_salary*12)/100
print("taxes",taxes)
net_pay=basic_salary-taxes
print("net pay",net_pay)
# Out:
# enter your payroll number: 2536
# enter enployee name: uio
# enter your gender: male
# enter your job group: k
# enter your basic salary: 7890
# invalid job group allowance
#  gross_pay 7890
# taxes 946.8
# net pay 6943.2

# %%
#employees alloance
