# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
Book1 = pd.read_excel("/content/Book1.xlsx")

# %%
Book1.plot()#quick visual check of the data
# Out:
# <Axes: >

# %%
Book1['ant.b']plot()

# %%
#ploting of scatter plots
Book1.plot.scatter(x='Ozone',y='Solar.R')#scatter plots
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ozone'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_505/240045386.py in <cell line: 0>()
#       1 #ploting of scatter plots
# ...

# %%
#ploting box plots
Book1.plot.box()#box plots
# Out:
# <Axes: >

# %%
#separate sub plots
Book1.plot.area(figsize=(12,4),subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)
