# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/wambua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cars=["toyota","audi","G63","F450"]
# cars.apped("bentley")
# cars.append("nissan")
# print(cars)
# print(len(cars))

# %%
#empty list
empty_list=[]
empty_list.append('a')
empty_list.append('b')
print(empty_list)
del empty_list[0]
print(empty_list)
# Out:
# ['a', 'b']
# ['b']

# %%
#tuples
numbers=(1,2,3,4,5)
print(numbers)
print(numbers[0])

                                  #properties of tuples
#1. OrderedTuples maintain the order of elements.t = (10, 20, 30)print(t[0])  # 10
#2. ImmutableOnce created, you cannot modify, add, or remove elements.t = (1, 2, 3)
# t[0] = 5  ❌ Error
#3. Allow duplicate valuesTuples can contain repeated elements.t = (1, 2, 2, 3)
#4. Can store multiple data typesA tuple can hold different types of data.t = (1, "hello", 3.5, True)
#5. Indexed and sliceableYou can access elements using indexing and slicing.t = (10, 20, 30, 40)print(t[1:3])  # (20, 30)
#6. Faster than listsBcause they are immutable, tuples are generally more memory-efficient and faster than lists.

#7. Hashable (if elements are hashable)Tuples can be used as keys in dictionaries if all their elements are immutable.d = {(1, 2): "value"}
#8. Supports nestingTuples can contain othertuples (or lists).t = ((1, 2), (3, 4))
#9. Packing and unpackingTuples support grouping and extracting values easily.t = (1, 2, 3)   # packinga, b, c = t     # unpacking
# Out:
# (1, 2, 3, 4, 5)
# 1

# %%
#capital cities
country_capitals={
    "germany":"berlin",
    "canada":"ottawa",
    "kenya":"nairobi",
    "england":"london",
    "belgium":"antwerp",#keys are immutable
    "USA":"washington DC"
}
print(country_capitals)
print(country_capitals["germany"])
print(country_capitals)
country_capitals["italy"]="rome"
country_capitals["belgium"]="brussles"
print(country_capitals)
#properties of dictionaries
#1. Unordered (in concept)
#2. Mutable
#3. Keys must be unique
#4. Keys must be immutable
                #finding length of a dictionary
# Out:
# {'germany': 'berlin', 'canada': 'ottawa', 'kenya': 'nairobi', 'england': 'london', 'belgium': 'antwerp', 'USA': 'washington DC'}
# berlin
# {'germany': 'berlin', 'canada': 'ottawa', 'kenya': 'nairobi', 'england': 'london', 'belgium': 'antwerp', 'USA': 'washington DC'}
# {'germany': 'berlin', 'canada': 'ottawa', 'kenya': 'nairobi', 'england': 'london', 'belgium': 'brussles', 'USA': 'washington DC', 'italy': 'rome'}
