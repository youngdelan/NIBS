# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/delan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cars=["toyota","audi","G63","F450"]
# cars.apped("bentley")
# cars.append("nissan")
# print(cars)
# print(len(cars))

# %%
#empty list
empty_list=[]
empty_list.append('a')
empty_list.append('b')
print(empty_list)
# Out:
# ['a', 'b']
