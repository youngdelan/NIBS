# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
cars=pd.read_excel("/Cars.xlsx")
cars.head() #displaying the first 5 rows
# Out:
#    Dodge  2018
# 0    Rs8  2020
# 1     M4  2013
# 2    CLS  2030
# 3    G63  1994
# 4  M14oi  1990

# %%
import pandas as pd
cars=pd.read_excel("/Cars.xlsx")
cars.dtypes #display the datatypes
# Out:
# Dodge    object
# 2018      int64
# dtype: object

# %%
import pandas as pd
cars=pd.read_excel("/Cars.xlsx")
cars.describe() #gives summary statistics
# Out:
#               2018
# count     9.000000
# mean   2011.888889
# std      12.484435
# min    1990.000000
# 25%    2012.000000
# 50%    2015.000000
# 75%    2017.000000
# max    2030.000000

# %%
dodge=cars["Dodge"]#selecting a specific collumn
print(dodge)
# Out:
# 0          Rs8
# 1           M4
# 2          CLS
# 3          G63
# 4        M14oi
# 5        Supra
# 6      Mustang
# 7    Maserrati
# 8      Buggati
# Name: Dodge, dtype: object

# %%
dodge=cars[['Dodge','2018']]#selecting two columns
dodge.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2921/1151431799.py in <cell line: 0>()
# ----> 1 dodge=cars[['Dodge','2018']]#selecting two columns
#       2 dodge.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
