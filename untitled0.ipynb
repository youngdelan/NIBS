# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Machine learning

#machine learning model:this are agents in machine learning based on feature:
#building machine learning models:
#1.Data collection  eg Kaggle
#2.Data cleaning-Remove unwanted things in the picture and resizing it.
#3.Split the data into training and testing data
#4.Choose a suitable machine learning algorithim:a) KNN(k-nearset neighbor)it is both a classifier and an editter
                                                  #:i)calculate the distance using the methods bellow:
                                                        #-Manhattan
                                                        #-Minwoski
                                                        #-Euclidean
                                                        #-Minkowski
                                                        #-Chebyshev
                                                  #:challenges in KNN:
                                                   #:if the distance is small during the search one tends to increase the radius of search.
                                               #:b)linear regression-used to make predictions
                                               #:c)Naive bayes
                                               #:d)Random forest
