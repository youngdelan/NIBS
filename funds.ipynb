# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/funds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#area of a sphere
import math
def area(radius):
    return 4*22/7*radius*radius
radius=float(input("enter radius of the sphere: "))
area=area(radius)
print("surface_area=",area)
# Out:
# enter radius of the sphere: 6
# surface_area= 452.57142857142856

# %%
#class bank_account
class bank_account:
    def __init__(self,owner,balance):
        self.owner=owner
        self.balance=balance
