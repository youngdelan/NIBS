# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/funds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#element 4 measuring distance using KNN
#manhattan distance-formula=|2D Space: |x₁ - x₂| + |y₁ - y₂|
#3D Space: |x₁ - x₂| + |y₁ - y₂| + |z₁ - z₂|
#minwoski\(X = (x_1, x_2, \dots, x_n)\) and \(Y = (y_1, y_2, \dots, y_n)\) in an n-dimensional space is defined as the p-th root of the sum of the p-th powers of the absolute differences between their coordinates:\(D(X,Y)=\left(\sum _{i=1}^{n}|{}x_{i}-y_{i}|{}^{p}\right)^{\frac{1}{p}}\)Where:n is the number of dimensions or features.\(x_{i}\) and \(y_{i}\)
#are the data values of points X and Y on the i-th dimension.p is the order parameter (where p ≥ 1).
#euchidian distance-1D Space (Number Line): \(d = \vert{}x_2 - x_1\vert{}\)2D Space (Plane): \(d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}\)3D Space (3D Object): \(d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2 + (z_2 - z_1)^2}\)
#n-Dimensional Space: \(d = \sqrt{\sum_{i=1}^{n} (x_{2i} - x_{1i})^2}\)


#METHODS OF REDUCING UNDERFITTING
'''
use more complex model
train on more eponhs(rounds)
add more features
'''
#REDUCING OVERFITTING
'''
collect more training data
reduce model complexity
clean noisy data
'''
#APPLICATIONS OF KNN
'''
content recommendation
Data pre-processing
Healthcare
Pattern recognition
'''
