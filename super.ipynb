# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/super.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#patient details
print("-----------WELCOME TO JESHI HOSPITAL----------")
name=input("name :")
gender=input("gender :")
age=input("age :")
residence=input("residence :")
print("name",name)
print("gender",gender)
print("age",age)
print("residence",residence)
#symptoms
print("symptoms")
symptom1=input("symptom1 :")
symptom2=input("symptom2 :")
symptom3=input("symptom3 :")
symptom4=input("symptom_4 :")
print("symptom1",symptom1)
print("symptom2",symptom2)

#disease
if(symptom1=="vomiting and diahria"):
 disease="typhoid"
elif(symptom2=="vomiting and fever"):
  disease="malaria"
elif(symptom3=="chest pain and wheezing sound"):
  disease="pneumonia"
elif(symptom4=="frequent urination and flucruation of sugar") :
  disease="diabities"
else:
 disease="unknown"
print("disease :",disease)
# Out:
# -----------WELCOME TO JESHI HOSPITAL----------
# name :kim
# gender :male
# age :89
# residence :kimbu
# name kim
# gender male
# age 89
# residence kimbu
# symptoms
# symptom1 :chest pain and wheezing sound
# symptom2 :vomiting and fever
# symptom3 :
# symptom_4 :
# symptom1 chest pain and wheezing sound
# symptom2 vomiting and fever
# disease : malaria
