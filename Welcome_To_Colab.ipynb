# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#functions
#they take up arguments and return values
      #syntax
      #list:#add
            #remove
            #update

# %%
#functions
def greetings ():
  print("hello functions")

greetings()
# Out:
# hello functions

# %%
#function with arguments
def myname():
  print("isaac")
myname()

def myname(name):
  print(name)
myname("isaac")
myname("jack")
# Out:
# isaac
# isaac
# jack

# %%
#function
def number(num1,num2):
  sum=num1+num2
  print(sum)
number(5,6)
# Out:
# 11

# %%
#a function that finds the square of a number
def square(num):
  print(num*num)
square(5)
# Out:
# 25

# %%
#a function that the multiplication of the numbers
def multiply(num1,num2):
  print(num1*num2)
multiply(5,6)
# Out:
# 30

# %%
#a function that determines if a number is even or odd
def even_odd(num):
  if num%2==0:
    print("even")
    print(f"{num}is even")
  else:
    print("odd")
    print(f"{num}is odd")
even_odd(10)
# Out:
# even
# 10is even

# %%
#passing user input as an argument

# %% [markdown]
# #passing user input as an argument
# def even_odd(num):
#   if num%2==0:
#     print("even")
#   else:
#     print("odd")
#
# num1=int(input("enter a number"))
# even_odd(num1)

# %%
#return
def addtwonumbers(num1,num2):
  return num1+num2
addition=addtwonumbers(10,20)
print(addition)
# Out:
# 30
