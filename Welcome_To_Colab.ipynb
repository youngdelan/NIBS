# %% [markdown]
# <a href="https://colab.research.google.com/github/youngdelan/NIBS/blob/master/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#execute the code
age=15
if (age>=18):
  {

  }
  print("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# not eligible to vote

# %%
#execute the code
age=15
if (age>=18):
  {


  print("eligible to vote")
  }
else:
   {
        print("not eligible to vote")
    }
# Out:
# not eligible to vote

# %%
num = int(input("enter a number"))
if (num>=0):
  {
print("number is positive")
  }
else:{

print("number is negative")
    }
# Out:
# enter a number-56
# number is negative

# %%
light=input("enter traffic color")

if light=="red":
  print("stop")
elif light==("yellow"):
  print("ready")
elif light==("green"):
  print("go")
else:
  print("invalid input")
# Out:
# enter traffic colorgreen
# go

# %%
#traffic colors
color=["red","yellow","green"]
print(color)

print(color[0])
print(color[1])
print(color[2])
# Out:
# ['red', 'yellow', 'green']
# red
# yellow
# green

# %%
#cars
cars=["escalede","dodge","pagani","ashton martin","F450"]
cars.append("dodge")
cars.insert(3,"pagani")
cars.remove("dodge")
print(cars)
# Out:
# ['escalede', 'pagani', 'pagani', 'ashton martin', 'F450', 'dodge']
